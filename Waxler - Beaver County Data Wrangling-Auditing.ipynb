# %% [markdown]
# ## OpenStreetMap Data Case Study
#
# #### Map Area
#
# Beaver County, PA, US and minor outlying and surrounding areas
#
# http://beavercountypa.gov/Pages/Default.aspx
#
#
# This region is where I live, where I currently work from home, and volunteer as a firefigher & EMT. I'm curious how much data has been entered for this somewhat rural community.
#
# ![alt text](image.png "Beaver County PA")

# %% [markdown]
# ### Problems Encountered in Map Data
#
# Below I created a sample subset and examined some of the data.
#
# Problems encountered included:
#
# 1. Inconsistently abbreviated street types, including Blvd, Tpke, St etc.
# 2. Problem characters within the listings
# 3.

# %%
#Importing useful python elements to examine data.
import xml.etree.ElementTree as ET
import pprint
from collections import defaultdict
import re
import csv
import codecs
import cerberus
import sqlite3
import os

OSM_FILE = "BeaverCounty.osm" # My OSM file of Beaver County, PA 
SAMPLE_FILE = "BeaverCountySample.osm" # My sample file to be created below 

k = 10 # Take every 10th element from the top level tags.

def get_element(osm_file, tags=('node', 'way', 'relation')):
    context = iter(ET.iterparse(osm_file, events=('start', 'end')))
    _, root = next(context)
    for event, elem in context:
        if event == 'end' and elem.tag in tags:
            yield elem
            root.clear()

with open(SAMPLE_FILE, 'wb') as output:
    output.write('<?xml version="1.0" encoding="UTF-8"?>\n'.encode())
    output.write('<osm>\n'.encode())

    # Write every kth top level element
    for i, element in enumerate(get_element(OSM_FILE)):
        if i % k == 0:
            output.write(ET.tostring(element, encoding='utf-8'))

    output.write('</osm>'.encode())

# %%
# Get the file size
os.stat('BeaverCounty.osm')
# Out:
# os.stat_result(st_mode=33206, st_ino=844424930873890, st_dev=2523738793, st_nlink=1, st_uid=0, st_gid=0, st_size=105381578, st_atime=1601126653, st_mtime=1601126653, st_ctime=1601126629)

# %% [markdown]
# ### File Statistics:
# File is 105381578 bytes, or 105.381578 Megabytes (st_size=105381578)
#
# #### We will count elements, get unique users and list them, to compare with our SQL later:

# %%
# Count the number of each type of tag in main OSM file

def count_tags(filename):
    tree=ET.iterparse(filename)
    tags={}
    for event,elem in tree:
        if elem.tag not in tags.keys():
            tags[elem.tag]=1
        else:
            tags[elem.tag] = tags[elem.tag]+1
    return tags    
    
with open(OSM_FILE,'rb') as f:
    tags=count_tags(OSM_FILE)
    pprint.pprint(tags)
f.close()
# Out:
# {'bounds': 1,
#  'member': 25791,
#  'meta': 1,
#  'nd': 551791,
#  'node': 478084,
#  'note': 1,
#  'osm': 1,
#  'relation': 940,
#  'tag': 181551,
#  'way': 53020}

# %%
# Find the number of users who have updated Beaver County, and list them.

def get_users(element):
    return element.get('user')


def process_users(filename):
    users = set()
    for _, element in ET.iterparse(filename):
        if element.get('user'):
            users.add(get_users(element))
        element.clear()    
    return users


with open(OSM_FILE,'rb') as f:
    users = process_users(OSM_FILE)

print(len(users))
pprint.pprint(users)
f.close()
# Out:
# 814
# {'-Schwarz-',
#  '1 Piece',
#  '16ajmain',
#  '25or6to4',
#  '42429',
#  'AJRAJR',
#  'Aaron Musick',
#  'AbbyO12',
#  'Adam Killian',
#  'Adam_P',
#  'Adamant1',
#  'Alan Trick',
#  'Alma Ross',
#  'AndreThib',
#  'AndrewBuck',
#  'AndrewSnow',
#  'AnonymousAlligator',
#  'Anthony Jantzi',
#  'AnthonyJackman',
#  'ArminGh',
#  'Ashley3870',
#  'Asphaze',
#  'Aurimas Fišeras',
#  'BMBurgh',
#  'Bacon_BMW',
#  'BeholdersEye',
#  'Bhojaraj',
#  'BiIbo',
#  'Bike Rider 9591',
#  'Bored',
#  'Brandon Saccomanno',
#  'Brian Herskovitz',
#  'Caitlin Downes',
#  'California Bear',
#  'Calwbb5',
#  'CamelCaseNick',
#  'Captblack13',
#  'Cato_d_Ae',
#  'Caulin',
#  'Cheeto',
#  'Christoph Lotz',
#  'Claytonlukes77',
#  'CloCkWeRX',
#  'Cody23yo',
#  'ColbertDolbert',
#  'Cory1',
#  'DJ FQA',
#  'DLichti',
#  'Dami_Tn',
#  'Dan C1234',
#  'Dan Wood',
#  'Daneel76',
#  'DannyAiquipa',
#  'DaveHansenTiger',
#  'Delaney C',
#  'Der Landvermesser',
#  'DevinBl1230',
#  'Dion Dock',
#  'DonHohman',
#  'DonovanG',
#  'DougV',
#  'Dowluri',
#  'Dr Kludge',
#  'DylanHC',
#  'ELadner',
#  'EdSS',
#  'Edbo',
#  'Edward',
#  'Egazda',
#  'ElliottPlack',
#  'EmlynSquare',
#  'Fantômas',
#  'Faster_Than_The_World',
#  'Fivea',
#  'Fluffy89502',
#  'Fredlyfish4',
#  'FrogTrain',
#  'FvGordon',
#  'GRailMapper',
#  'Garrett51!',
#  'Gary Hayden',
#  'GeeTee87',
#  'General Updating',
#  'GeoKitten',
#  'GeoKitten_import',
#  'Geogast',
#  'GerdP',
#  'GreenRunner0',
#  'Guylamar2006',
#  'Heffer',
#  'HighOnBluegrass',
#  'Hobgoblin',
#  'HubMiner',
#  'IBnM',
#  'Ian Bonnell',
#  'IanFarrar',
#  'Imp_GL',
#  'Iowa Kid',
#  'Ivan Komarov',
#  'JBizzle',
#  'JGreenleaf',
#  'JJD17',
#  'JRH50',
#  'Jaben428',
#  'Jack the Ripper',
#  'JacobHazelbach48',
#  'Jakethedog2004',
#  'Jamarkle',
#  'Jared Krut',
#  'Jarl67',
#  'Jean-Marc Liotier',
#  'Jedrzej Pelka',
#  'Jeff Bearer',
#  'Jerry Cant',
#  'JessAk71',
#  'Jinglesgs4l',
#  'JoeyBro',
#  'Johnny Mapperseed',
#  'Jothirnadh',
#  'Jowzjan',
#  'JulienBalas',
#  'KR-KRKR-KR',
#  'KallanP',
#  'Karin289',
#  'Karthoo',
#  'Karthoo_import',
#  'Kerbaswh',
#  'KristenK',
#  'Kurly',
#  'Lackzoom',
#  'Letelier',
#  'Lilla Elna',
#  'Lisa McCune-Noll_Roadbotics',
#  'Lore Sjoberg',
#  'LucasK271',
#  'Lucitucci',
#  'Luis Garcia-Lopez',
#  'Luis36995',
#  'MBedilion',
#  'MCollar',
#  'MR1457',
#  'MargoonLagoon',
#  'Margori123',
#  'Mark Gray',
#  'Matt Toups',
#  'Matt1993',
#  'Med',
#  'MidwestMapGeek',
#  'Mike Johnston',
#  'Mike Muder',
#  'MikeN',
#  'Milenko',
#  'Minh Nguyen',
#  'Moduspwnens',
#  'Mushroom Man',
#  'N50',
#  'NE2',
#  'Nate Wessel',
#  'Natfoot',
#  'NicRoets',
#  'Nick Faughey',
#  'NickBolten',
#  'Nimbalo',
#  'Northfork',
#  'OSchlüter',
#  'Oberpfälzer',
#  'OklaNHD',
#  'Olyon',
#  'Omnific',
#  'PHerison',
#  'Pamela WV',
#  'Panchopage2',
#  'Parmiggano',
#  'Pennsyltucky',
#  'Peter14',
#  'PeterEastern',
#  'Pnrrth',
#  'Porsche904',
#  'Premsakhare',
#  'Pudu',
#  'Quantum Fire',
#  'R0bst3r',
#  'Raccoon!',
#  'Rat_catche',
#  'RetiredInNH',
#  'RichRico',
#  'Richard',
#  'RichieMcEwen',
#  'RoadGeek_MD99',
#  'Roadsguy',
#  'SHPD',
#  'SK53',
#  'Sacajawea',
#  'SamSamRobert',
#  'Sarr_Cat',
#  'Scharf Energy Systems',
#  'ScottGunther',
#  'Shadus',
#  'Sigourni',
#  'SimonPoole',
#  'Skybunny',
#  'SomeoneElse_Revert',
#  'Somya Vats',
#  'Spanholz',
#  'StellanL',
#  'TIGERcnl',
#  'Takuto',
#  'Taxiarchos',
#  'TediouslyBored',
#  'Tenedor',
#  'TheDutchMan13',
#  'Timothy Smith',
#  'ToeBee',
#  'Tom_Holland',
#  'TorCguy',
#  'TortillaScot',
#  'US Woods',
#  'Uffda243',
#  'Uniplex',
#  'Vid the Kid',
#  'Viki_travel_weak',
#  'Vkkalegi',
#  'Wampa',
#  'Wampahoofus',
#  'WoodWoseWulf',
#  'YEMIA',
#  'Yaten',
#  'Zachy_P',
#  'ZenithTheFox',
#  'a_isaeva',
#  'aaelizasansbury',
#  'abbafei',
#  'abel801',
#  'abhap',
#  'abvincen',
#  'accheela',
#  'achantav',
#  'adam820',
#  'adamos',
#  'adhya1',
#  'aggopak',
#  'agnisn',
#  'ahabdu',
#  'akalohri',
#  'alefvanoon',
#  'alixhartmann',
#  'almaasm',
#  'amarajz',
#  'ambarapu',
#  'amillar',
#  'amitbish',
#  'amithrav',
#  'ammhita',
#  'amzmkuma',
#  'amznruth',
#  'ananon',
#  'andreeab_telenav',
#  'andrewpmk',
#  'andrewrpucci',
#  'andygol',
#  'anjbe',
#  'antoalvi',
#  'anukrits',
#  'anurasi',
#  'appank',
#  'aps',
#  'arehaan',
#  'arkdatta',
#  'arnolden13',
#  'arosalon',
#  'arpremna',
#  'asa5218',
#  'asanapal',
#  'asddiqu',
#  'ashbeesa',
#  'ashleyannmathew',
#  'ashradha',
#  'asrdd',
#  'atomwaffen',
#  'attaragi',
#  'avssr',
#  'ayushiso',
#  'b-jazz',
#  'b-jazz-bot',
#  'bachurev',
#  'bahnpirat',
#  'baigzake',
#  'baindran',
#  'balcoath',
#  'bapup',
#  'bathis',
#  'befit1',
#  'begumfai',
#  'bhaller',
#  'bhardwk',
#  'bhavana naga',
#  'bhavant',
#  'bhietsch',
#  'bhiy',
#  'bingo',
#  'bjnlm',
#  'black_bike',
#  'bmmh',
#  'bnilima',
#  'boblisa',
#  'boddushr',
#  'boeleman81',
#  'bogdan_andrei',
#  'boopington',
#  'borvikas',
#  'bot-mode',
#  'buchula',
#  'buddhirv',
#  'bwarren',
#  'calfarome',
#  'catalinad_telenav',
#  'cforin',
#  'chagasru',
#  'chandeek',
#  'changurl',
#  'chatrags',
#  'chaturvh',
#  'chauaak',
#  'chazanov',
#  'chdr',
#  'chekasat',
#  'chepteja',
#  'chharsha',
#  'chhava',
#  'choess',
#  'chosayan',
#  'clay_c',
#  'compass26',
#  'cristiang_telenav',
#  'crookedcafe',
#  'cswaroo',
#  'czwalga',
#  'daggarw',
#  'daleyt',
#  'danuta_telenav',
#  'dasnei',
#  'datbrahm',
#  'davidearl',
#  'dcat',
#  'dchiles',
#  'debanka',
#  'debott',
#  'deepikja',
#  'dekatherm',
#  'derekh147',
#  'desuman',
#  'devapujk',
#  'devasen',
#  'devratc',
#  'dhaird',
#  'dhakanth',
#  'didier2020',
#  'dirtyidol',
#  'djdigital',
#  'dmgroom_ct',
#  'domcamp',
#  'dpaschich',
#  'dppola',
#  'duarisha',
#  'dufekin',
#  'dviraja',
#  'dvyasha',
#  'dwelch67',
#  'dyellak',
#  'eadamk',
#  'ebt12',
#  'ediyes',
#  'ee_matze',
#  'ejjoshy',
#  'ekkakkas',
#  'emilieteresehovanec',
#  'emj',
#  'enlow',
#  'epetronick',
#  'eric22',
#  'erieninja',
#  'ethylisocyanat',
#  'fixedbusiness',
#  'foxox',
#  'fredjunod',
#  'freebeer',
#  'frstbubble',
#  'gabis_telenav',
#  'gadipeh',
#  'ganarend',
#  'gandlur',
#  'gassc',
#  'gauraan',
#  'gazsri',
#  'gdodlapa',
#  'geckomapper',
#  'geozeisig',
#  'gilasri',
#  'gireeshn',
#  'gleissmap',
#  'gohimans',
#  'gollabg',
#  'goraia',
#  'gormur',
#  'govvala',
#  'grandhs',
#  'gregcrago',
#  'greggerm',
#  'grubuloidX X',
#  'gsravya',
#  'gsravya1',
#  'gujelapg',
#  'gundanar',
#  'h4ck3rm1k3',
#  'harishwr',
#  'harpreo',
#  'harshjs',
#  'herrick67',
#  'himabudd',
#  'himansne',
#  'hno2',
#  'hobbesvsboyle',
#  'hofoen',
#  'homeslice60148',
#  'houston_mapper1',
#  'howdystranger',
#  'hpeddir',
#  'hzs5199',
#  'iandees',
#  'iggujja',
#  'inagans',
#  'indukun',
#  'interdite',
#  'ioanam_telenav',
#  'ionutr_telenav',
#  'irasesu',
#  'j07red',
#  'jScher',
#  'jacobbraeutigam',
#  'jacorohi',
#  'jaiaka',
#  'jaimemd',
#  'jakkanen',
#  'jalajm',
#  'jamenimm',
#  'jangahari',
#  'javmoh',
#  'jdoncev',
#  'jdoniche',
#  'jedidy',
#  'jerjozwik',
#  'jgruca',
#  'jhameena',
#  'jharpster',
#  'jkoether',
#  'jleedev',
#  'jmpaxton',
#  'jojokant',
#  'jojoyal',
#  'jomsjaco',
#  'jonesydesign',
#  'jonwit_import',
#  'jotzt',
#  'jremillard',
#  'jsteelz',
#  'jtaji',
#  'jumbanho',
#  'jyotkuma',
#  'kanleela',
#  'kararcha',
#  'karitotp',
#  'karnatim',
#  'karragha',
#  'kartonage',
#  'kasals',
#  'kasbadri',
#  'katakp',
#  'kaurrupa',
#  'kavshnu',
#  'kedarnap',
#  'kevmath',
#  'khnzmnz',
#  'kirashas',
#  'kirrawat',
#  'kisaa',
#  'kkoganti',
#  'kkre1',
#  'kllahari',
#  'knikitha',
#  'kollipay',
#  'kotaprad',
#  'kotharu',
#  'krinkov76239',
#  'kshtdh',
#  'ksnghr',
#  'ksrilekh',
#  'ktsherbine0129',
#  'kuavula',
#  'kumartcx',
#  'kurugunk',
#  'kvss',
#  'kwametedros',
#  'lac838',
#  'leelamrs',
#  'lfriederman',
#  'limmmoh',
#  'livholley',
#  'lorandr_telenav',
#  'lou4606',
#  'loyakris',
#  'maakra',
#  'maggot27',
#  'mahmedqg',
#  'maitsana',
#  'majumdea',
#  'makkera',
#  'manikyal',
#  'manitec',
#  'mansipan',
#  'mapalla',
#  'mapman44',
#  'markm851003',
#  'marthaleena',
#  'mathpras',
#  'maxerickson',
#  'maxolasersquad',
#  'mbeyerle',
#  'mcingara',
#  'mdroads',
#  'menzo2003',
#  'methowmade',
#  'mey2008',
#  'michaedz',
#  'mihaii_telenav',
#  'mike140',
#  'miluethi',
#  'mirror176',
#  'mitesl',
#  'mmastlr',
#  'moalnzn',
#  'modukv',
#  'mohahase',
#  'mohapd',
#  'mrfa',
#  'mshahaba',
#  'msieckmann',
#  'msimm29',
#  'msten19',
#  'muziriana',
#  'mvexel',
#  'mvviveka',
#  'mwakram',
#  'mykol404',
#  'mzamam',
#  'naaitha',
#  'nacho319',
#  'nairnidh',
#  'nambim',
#  'nammala',
#  'nandinab',
#  'naresksv',
#  'nathan206',
#  'navlay',
#  'navuddin',
#  'navyam',
#  'nbhiss',
#  'nehnaaz',
#  'nembery',
#  'nfgusedautoparts',
#  'nickel715',
#  'nihaalr',
#  'nimmalab',
#  'nishisi',
#  'njtbusfan',
#  'nsripz',
#  'ntanniru',
#  'nyuriks',
#  'oanac2_telenav',
#  'oldtopos',
#  'oliver01',
#  'ombsz',
#  'ommundu',
#  'paasthan',
#  'pachpora',
#  'pancakebuttons',
#  'panchis1',
#  'pandypr',
#  'pangoSE',
#  'patadivy',
#  'patchez',
#  'pathkh',
#  'pavapati',
#  'payelgh',
#  'pbellamk',
#  'pbobbili',
#  'pbudhara',
#  'pdantojh',
#  'penimire',
#  'pghb',
#  'piligab',
#  'pillalp',
#  'piyuku',
#  'pkkv',
#  'pkoby',
#  'podishep',
#  'pokemonManPlz',
#  'poornibadrinath',
#  'ppallam',
#  'pppadal',
#  'prafupan',
#  'praghath',
#  'prakhasr',
#  'pramvyas',
#  'pravallg',
#  'presakha',
#  'purbitap',
#  'qsudarji',
#  'qureahme',
#  'racranji',
#  'rad1ance',
#  'rahuzod',
#  'raknm',
#  'ramayang',
#  'ramijcr',
#  'ramyaragupathy',
#  'rapush',
#  'raupach',
#  'ravsjith',
#  'rbhawa',
#  'rekasruj',
#  'rekulc1',
#  'reswara',
#  'revent',
#  'rfulop',
#  'rickmastfan67',
#  'ridixcr',
#  'ridixcr_import',
#  'riskhann',
#  'riteshaw',
#  'rithikaj',
#  'riysingh',
#  'rkkarnee',
#  'rkkasams',
#  'roberts_telenav',
#  'robleiphart',
#  'robliebhart',
#  'rojganes',
#  'rpakma',
#  'rppalagu',
#  'rprescott',
#  'rrkum',
#  'ruthmaben',
#  'rverdu',
#  'ryandrake',
#  'rzsi',
#  'sabaamzn',
#  'sabok',
#  'sahanki',
#  'saikariv',
#  'sailajc',
#  'sainiyam',
#  'sakraa',
#  'saksudan',
#  'salix01',
#  'samely',
#  'sanbukke',
#  'sandchi',
#  'sandhill',
#  'sanganh',
#  'sankethn',
#  'sansglu10',
#  'sanuhya',
#  'sartsuri',
#  'sawhs',
#  'saxvidit',
#  'scharith',
#  'scratchspin',
#  'sctrojan79',
#  'seantosz',
#  'sebastic',
#  'semwalas',
#  'sggundl',
#  'sgmamz',
#  'sgudiva',
#  'shabkhat',
#  'shadty',
#  'shargrac',
#  'shasband',
#  'shasharv',
#  'shaspand',
#  'shawat94',
#  'shelinestaxster',
#  'shkshar',
#  'shortsgq',
#  'shoshibu',
#  'shravan91',
#  'shreeush',
#  'shushmit',
#  'siayu',
#  'siddhaam',
#  'sijjacob',
#  'silakshm',
#  'sinreeya',
#  'sireeshp',
#  'sites-manager',
#  'sivachak',
#  'sivaib',
#  'sivapaid',
#  'skharwal',
#  'skquinn',
#  'smbharan',
#  'snghcvv',
#  'snickerdoodles',
#  'snyash',
#  'somanch',
#  'soumybha',
#  'soundred',
#  'spavulur',
#  'sreejam',
#  'sreelekk',
#  'srigirip',
#  'srirohan',
#  'srividya_c',
#  'srmudava',
#  'srygy',
#  'ssahithi',
#  'ssange',
#  'sskalyan',
#  'sssmc',
#  'stevea',
#  'steverumizen',
#  'sttbss',
#  'stucki1',
#  'sunaman',
#  'sunilaak',
#  'sunilvs',
#  'sushredd',
#  'svarkey',
#  'svvakkal',
#  'swappa',
#  'swarnimv',
#  'swarood',
#  'swathiku',
#  'swimdb',
#  'syrah1',
#  'tahuram',
#  'talukdm',
#  'tammpava',
#  'tcao@transloc',
#  'tebiggs',
#  'tejkante',
#  'teliks',
#  'teodorab_telenav',
#  'terrah27',
#  'thaggela',
#  'timlag1305',
#  'tmadhuli',
#  'tqh5390',
#  'tusnayak',
#  'tvineela',
#  'twiztidtunes',
#  'twra',
#  'uhhany1',
#  'unnsyeda',
#  'user_5359',
#  'utkap',
#  'utkshukl',
#  'vaibkaus',
#  'vaidhev',
#  'vardhamk',
#  'varmasa',
#  'varshia',
#  'vasamd',
#  'vatsomya',
#  'vbbukka',
#  'vchndl',
#  'veesams',
#  'venkakaz',
#  'vinitht',
#  'vissushm',
#  'vjjeevan',
#  'vkanduku',
#  'vkatredd',
#  'vmonisha',
#  'vogelfreier',
#  'volatile_ant',
#  'vpprahar',
#  'vsahith',
#  'vshnsa',
#  'vvrddy',
#  'vvvnm',
#  'vvvuppal',
#  'vysyarp',
#  'wegavision',
#  'werner2101',
#  'wheelmap_visitor',
#  'wolfgang8741',
#  'woodpeck_fixbot',
#  'woodpeck_repair',
#  'woody121',
#  'wvdp',
#  'xybot',
#  'yadathot',
#  'yallasan',
#  'yaswap',
#  'yaugenka',
#  'yerramg',
#  'yerrawa',
#  'ynglt',
#  'yurasi',
#  'zdcorrea',
#  'zephyr',
#  'zeromap',
#  'zmankits'}

# %%
# Check formatting of the K attribute in the tags in the OSM file, code referenced from Udacity & Github
#

lower = re.compile(r'^([a-z]|_)*$')
lower_colon = re.compile(r'^([a-z]|_)*:([a-z]|_)*$')
problemchars = re.compile(r'[=\+/&<>;\'"\?%#$@\,\. \t\r\n]')


def key_type(element, keys):
    if element.tag == "tag":
        if lower.search(element.attrib['k']):
            keys['lower'] += 1
        elif lower_colon.search(element.attrib['k']):
            keys['lower_colon'] += 1
        elif problemchars.search(element.attrib['k']):
            keys['problemchars'] = keys['problemchars'] + 1
        else:    
            keys['other'] += 1  
            print(element.attrib['k'])
            print(element.attrib['v'])
    return keys


def process_keys_map(filename):
    keys = {"lower": 0, "lower_colon": 0, "problemchars": 0, "other": 0}
    for _, element in ET.iterparse(filename):
        keys = key_type(element, keys)

    return keys

with open(OSM_FILE,'rb') as f:
    keys = process_keys_map(OSM_FILE)
    pprint.pprint(keys)
f.close()
# Out:
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Beaver
# gnis:County_num
# 007
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# gnis:Class
# Populated Place
# gnis:County
# Allegheny
# gnis:County_num
# 003
# gnis:ST_alpha
# PA
# gnis:ST_num
# 42
# FIXME
# Exactly where is the east end of current trackage?
# voltage-high
# 345000
# voltage-high
# 345000
# socket:type1
# 2
# socket:type1
# yes
# socket:type1
# 2
# railway:signal:direction
# forward
# railway:signal:position
# right
# railway:signal:direction
# forward
# railway:signal:position
# right
# name_1
# Raccoon Township Police Department
# name_1
# Crestridge Drive
# tiger:name_base_1
# Crestridge
# tiger:name_type_1
# Dr
# tiger:zip_left_1
# 15046
# tiger:zip_left_1
# 15046
# tiger:zip_left_1
# 15143
# tiger:zip_right_1
# 15143
# name_1
# Clinton Flaugherty Road
# tiger:name_base_1
# Clinton Flaugherty
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15143
# tiger:zip_left_2
# 15143
# tiger:zip_left_3
# 15143
# tiger:zip_right_3
# 15143
# name_1
# Shousetown Bridge
# tiger:name_base_1
# Shousetown
# tiger:name_type_1
# Brg
# tiger:name_base_1
# Lincoln
# tiger:name_type_1
# Hwy
# tiger:zip_left_1
# 15143
# tiger:zip_left_1
# 15126
# name_1
# Winnwood Road
# tiger:name_base_1
# Winnwood
# tiger:name_type_1
# Rd
# name_1
# Winter Trail
# tiger:name_base_1
# Winter
# tiger:name_type_1
# Trl
# tiger:zip_left_1
# 15143
# name_1
# Cherry Street
# tiger:name_base_1
# Cherry
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15126
# tiger:zip_left_2
# 15126
# tiger:zip_left_3
# 15126
# tiger:zip_right_2
# 15126
# name_1
# State Route 3071
# tiger:name_base_1
# State Route 3071
# tiger:zip_left_1
# 15108
# name_1
# Corplimit
# tiger:name_base_1
# Corplimit
# name_1
# Grove Street
# tiger:zip_left_1
# 15046
# name_1
# Lytton Drive
# tiger:name_base_1
# Lytton
# tiger:name_type_1
# Dr
# name_1
# State Route 3071
# tiger:name_base_1
# State Route 3071
# tiger:zip_left_1
# 15046
# tiger:zip_left_1
# 15046
# tiger:zip_left_1
# 15143
# tiger:zip_left_2
# 15143
# tiger:zip_right_2
# 15143
# tiger:name_base_1
# Orange Beltway
# tiger:name_base_1
# Orange Beltway
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15046
# tiger:zip_left_1
# 15108
# tiger:zip_right_1
# 15046
# tiger:zip_left_1
# 15046
# tiger:zip_left_2
# 15046
# tiger:zip_left_3
# 15108
# tiger:zip_left_4
# 15108
# tiger:zip_right_4
# 15108
# tiger:zip_left_1
# 15026
# tiger:zip_right_1
# 15026
# tiger:zip_left_1
# 15026
# tiger:zip_left_1
# 15108
# tiger:zip_right_1
# 15108
# name_1
# Pine Hollow Road
# tiger:name_base_1
# Pine Hollow
# tiger:name_type_1
# Rd
# name_1
# Gaffney Avenue
# tiger:name_base_1
# Gaffney
# tiger:name_type_1
# Ave
# name_1
# Thorn Street
# tiger:name_base_1
# Thorn
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15108
# tiger:zip_left_1
# 15143
# tiger:zip_right_1
# 15143
# tiger:zip_left_1
# 15046
# tiger:zip_right_1
# 15046
# tiger:zip_left_1
# 15143
# tiger:zip_left_1
# 15108
# tiger:zip_left_1
# 15026
# name_1
# Highview Drive
# tiger:name_base_1
# Highview
# tiger:name_type_1
# Dr
# tiger:zip_left_1
# 15143
# tiger:zip_right_1
# 15143
# name_1
# River Street
# tiger:name_base_1
# River
# tiger:name_type_1
# St
# name_1
# Beaver Road
# tiger:name_base_1
# Beaver
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15056
# tiger:zip_left_1
# 15108
# tiger:zip_left_1
# 15108
# tiger:zip_right_1
# 15108
# name_1
# Project Road
# tiger:name_base_1
# Project
# tiger:name_type_1
# Rd
# name_1
# T447
# tiger:name_base_1
# T447
# name_1
# T476
# tiger:name_base_1
# T476
# name_1
# T348
# tiger:name_base_1
# T348
# name_1
# Peoples Street
# tiger:name_base_1
# Peoples
# tiger:name_type_1
# St
# name_1
# Tyler Street
# tiger:name_base_1
# Tyler
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15001
# name_1
# Terrace Avenue
# tiger:name_base_1
# Terrace
# tiger:name_type_1
# Ave
# destination:ref:backward
# PA 18 South
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# tiger:zip_left_1
# 15074
# tiger:zip_left_2
# 15074
# tiger:zip_left_3
# 15074
# tiger:zip_right_1
# 15074
# tiger:zip_right_2
# 15074
# tiger:zip_right_3
# 15074
# tiger:name_base_1
# Beaver Valley
# tiger:name_type_1
# Expy
# tiger:name_base_1
# Beaver Valley
# tiger:name_type_1
# Expy
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# name_1
# State Route 1009
# tiger:name_base_1
# State Route 1009
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# name_1
# State Route 1005
# name_1
# Fry Drive
# tiger:name_base_1
# Fry
# tiger:name_type_1
# Dr
# name_1
# Frishcorn Road
# tiger:name_base_1
# Frishcorn
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 16136
# tiger:zip_right_1
# 16136
# tiger:zip_left_1
# 15061
# FIXME
# What's the street name?
# tiger:name_base_1
# State Route 251
# tiger:zip_left_1
# 15001
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15108
# tiger:zip_left_3
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_right_3
# 15001
# tiger:zip_left_1
# 15010
# tiger:zip_left_1
# 16115
# name_1
# T350
# tiger:name_base_1
# T350
# name_1
# Rambo Dirt Road
# name_2
# T350
# tiger:name_base_1
# Rambo Dirt
# tiger:name_base_2
# T350
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_right_2
# 15001
# tiger:zip_left_1
# 15081
# tiger:zip_right_1
# 15081
# name_1
# State Route 2006
# tiger:name_base_1
# State Route 2006
# name_1
# Linda Drive
# tiger:name_base_1
# Linda
# tiger:name_type_1
# Dr
# name_1
# Front Street
# tiger:name_base_1
# Front
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15061
# name_1
# T 516
# tiger:name_base_1
# T 516
# name_1
# Virginia Avenue
# tiger:name_base_1
# Virginia
# tiger:name_type_1
# Ave
# tiger:zip_left_1
# 15066
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# name_1
# Township Highway 1049
# tiger:name_base_1
# Township Highway 1049
# name_1
# Township Highway 1049
# tiger:name_base_1
# Township Highway 1049
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:zip_right_1
# 16141
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 15010
# tiger:zip_right_1
# 15010
# NHS
# yes
# tiger:name_base_1
# State Route 68
# name_1
# State Route 1028
# tiger:name_base_1
# State Route 1028
# tiger:zip_left_1
# 15066
# tiger:zip_right_1
# 15066
# tiger:zip_left_1
# 15001
# tiger:zip_left_1
# 15026
# tiger:zip_left_1
# 15010
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15010
# tiger:zip_right_1
# 15010
# name_1
# Kenny Drive
# tiger:name_base_1
# Kenny
# tiger:name_type_1
# Dr
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:zip_left_1
# 15052
# name_1
# T369
# tiger:name_base_1
# T369
# tiger:zip_left_1
# 15009
# name_1
# T454
# tiger:name_base_1
# T454
# name_1
# Unionville Road
# tiger:name_base_1
# Unionville
# tiger:name_type_1
# Rd
# NHS
# yes
# tiger:name_base_1
# State Route 68
# name_1
# Unionville Road
# tiger:name_base_1
# Unionville
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15010
# parking:lane:both
# parallel
# name_1
# State Route 3023
# tiger:name_base_1
# State Route 3023
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_left_1
# 15001
# name_1
# T456
# tiger:name_base_1
# T456
# tiger:name_base_1
# State Route 168
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15009
# tiger:zip_right_1
# 15009
# parking:lane:both
# parallel
# name_1
# Sunnyview Drive
# tiger:name_base_1
# Sunnyview
# tiger:name_type_1
# Dr
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# T383
# tiger:name_base_1
# T383
# name_1
# T312
# tiger:name_base_1
# T312
# name_1
# Hartman Way
# tiger:name_base_1
# Hartman
# tiger:name_type_1
# Way
# tiger:zip_left_1
# 16117
# tiger:zip_right_1
# 16117
# name_1
# T493
# tiger:name_base_1
# T493
# tiger:zip_left_1
# 15050
# tiger:zip_left_1
# 15042
# name_1
# State Route 3016
# tiger:name_base_1
# State Route 3016
# name_1
# Maple Street
# tiger:name_base_1
# Maple
# tiger:name_type_1
# St
# name_1
# T490
# tiger:name_base_1
# T490
# tiger:zip_left_1
# 15061
# tiger:zip_right_1
# 15061
# name_1
# Frankfort Springs Road
# tiger:name_base_1
# Frankfort Springs
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15010
# tiger:zip_left_1
# 15074
# name_1
# T346
# tiger:name_base_1
# T346
# parking:lane:both
# parallel
# name_1
# Hiland Avenue
# tiger:name_base_1
# Hiland
# tiger:name_type_1
# Ave
# name_1
# Hiland Avenue
# tiger:name_base_1
# Hiland
# tiger:name_type_1
# Ave
# name_1
# Hiland Avenue
# tiger:name_base_1
# Hiland
# tiger:name_type_1
# Ave
# tiger:zip_left_1
# 15009
# tiger:zip_right_1
# 15009
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# tiger:zip_left_3
# 15001
# tiger:zip_right_1
# 15001
# tiger:name_base_1
# State Route 151
# tiger:name_base_1
# State Route 989
# name_1
# State Route 3042
# tiger:name_base_1
# State Route 3042
# name_1
# State Route 3042
# tiger:name_base_1
# State Route 3042
# tiger:zip_left_1
# 16115
# name_1
# Patterson Drive
# tiger:name_base_1
# Patterson
# tiger:name_type_1
# Dr
# tiger:zip_left_1
# 16117
# tiger:zip_left_2
# 16117
# name_1
# T 344
# tiger:name_base_1
# T 344
# name_1
# Wolf Run Road
# tiger:name_base_1
# Wolf Run
# tiger:name_type_1
# Rd
# tiger:name_base_1
# State Route 168
# tiger:zip_left_1
# 15001
# tiger:zip_left_1
# 15074
# tiger:name_base_1
# State Route 151
# tiger:name_base_1
# State Route 151
# tiger:zip_left_1
# 15001
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# name_1
# T518
# tiger:name_base_1
# T518
# tiger:zip_left_1
# 16157
# name_1
# State Route 1005
# tiger:name_base_1
# State Route 1005
# name_1
# T368
# tiger:name_base_1
# T368
# name_1
# T368
# tiger:name_base_1
# T368
# name_1
# Division Street
# tiger:name_base_1
# Division
# tiger:name_type_1
# St
# name_1
# T472
# tiger:name_base_1
# T472
# name_1
# T472
# tiger:name_base_1
# T472
# tiger:zip_left_1
# 15074
# tiger:zip_right_6
# 15074
# name_1
# T558
# tiger:name_base_1
# T558
# tiger:zip_left_1
# 15001
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_right_2
# 15001
# tiger:name_base_1
# State Route 51
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# parking:lane:both
# parallel
# tiger:zip_left_1
# 16117
# tiger:zip_left_1
# 15010
# tiger:zip_left_2
# 15010
# tiger:zip_left_3
# 15010
# name_1
# I-341
# name_2
# Rambo Road
# tiger:name_base_1
# I-341
# tiger:name_base_2
# Rambo
# tiger:name_type_2
# Rd
# name_1
# T356
# tiger:name_base_1
# T356
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# T318
# tiger:name_base_1
# T318
# tiger:name_base_1
# State Route 168
# tiger:zip_left_1
# 16115
# tiger:name_base_1
# State Route 168
# tiger:zip_left_1
# 16115
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# name_1
# Lindberg Avenue
# tiger:name_base_1
# Lindberg
# tiger:name_type_1
# Ave
# NHS
# yes
# name_1
# Township Road 709
# tiger:name_base_1
# Township Road 709
# name_1
# T302
# tiger:name_base_1
# T302
# name_1
# T483
# tiger:name_base_1
# T483
# tiger:zip_left_1
# 15043
# tiger:zip_left_1
# 15003
# tiger:zip_right_1
# 15003
# tiger:zip_left_1
# 15003
# tiger:zip_left_2
# 15003
# name_1
# State Route 1008
# tiger:name_base_1
# State Route 1008
# name_1
# T 487
# tiger:name_base_1
# T 487
# name_1
# T447
# tiger:name_base_1
# T447
# name_1
# State Route 3028
# tiger:name_base_1
# State Route 3028
# name_1
# T481
# tiger:name_base_1
# T481
# name_1
# Hoveler Avenue
# tiger:name_base_1
# Hoveler
# tiger:name_type_1
# Ave
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# maxspeed:hgv:forward
# 20 mph
# tiger:zip_left_1
# 15066
# name_1
# T466
# tiger:name_base_1
# T466
# name_1
# Blacks Woods Road
# tiger:name_base_1
# Blacks Woods
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15074
# tiger:zip_left_2
# 15042
# tiger:zip_right_2
# 15042
# tiger:zip_left_1
# 15010
# tiger:zip_left_2
# 15010
# tiger:zip_right_2
# 15010
# tiger:name_base_1
# State Route 989
# name_1
# 16th Avenue
# tiger:name_base_1
# 16th
# tiger:name_type_1
# Ave
# name_1
# T458
# tiger:name_base_1
# T458
# name_1
# Wayne Avenue
# tiger:name_base_1
# Wayne
# tiger:name_type_1
# Ave
# tiger:zip_left_1
# 15005
# tiger:zip_left_2
# 15005
# name_1
# State Route 1005
# tiger:name_base_1
# State Route 1005
# tiger:zip_left_1
# 16117
# tiger:zip_left_1
# 15066
# tiger:zip_right_1
# 15066
# name_1
# Pump Station Road
# tiger:name_base_1
# Pump Station
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15010
# tiger:name_base_1
# State Route 551
# name_1
# Gilliand Road
# tiger:name_base_1
# Gilliand
# tiger:name_type_1
# Rd
# name_1
# T319
# tiger:name_base_1
# T319
# tiger:name_base_1
# State Route 588
# tiger:zip_left_1
# 16141
# tiger:zip_left_2
# 16141
# parking:lane:left
# parallel
# parking:lane:right
# parallel
# tiger:zip_left_1
# 16117
# tiger:zip_left_2
# 16136
# tiger:zip_right_2
# 16136
# parking:lane:both
# parallel
# name_1
# Chestnut Street
# tiger:name_base_1
# Chestnut
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15081
# tiger:zip_left_3
# 15001
# name_1
# T492
# tiger:name_base_1
# T492
# tiger:zip_left_1
# 15009
# name_1
# Sr04339
# tiger:name_base_1
# Sr04339
# parking:lane:both
# parallel
# name_1
# Wilson Street
# tiger:name_base_1
# Wilson
# tiger:name_type_1
# St
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# tiger:name_base_1
# State Route 551
# tiger:name_base_1
# State Route 65
# parking:lane:both
# parallel
# name_1
# T 410
# tiger:name_base_1
# T 410
# tiger:zip_left_1
# 15010
# name_1
# Pine Run Road
# tiger:name_base_1
# Pine Run
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15061
# tiger:zip_right_1
# 15061
# tiger:zip_left_1
# 15061
# tiger:zip_right_1
# 15061
# name_1
# Fry Drive
# tiger:name_base_1
# Fry
# tiger:name_type_1
# Dr
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# name_1
# T544
# tiger:name_base_1
# T544
# tiger:zip_left_1
# 15001
# tiger:zip_left_1
# 15066
# name_1
# T486
# tiger:name_base_1
# T486
# name_1
# T329
# tiger:name_base_1
# T329
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# Shreeves Road
# name_2
# T303
# tiger:name_base_1
# Shreeves
# tiger:name_base_2
# T303
# tiger:name_type_1
# Rd
# NHS
# yes
# tiger:name_base_1
# State Route 51
# name_1
# T544
# tiger:name_base_1
# T544
# tiger:zip_left_1
# 15066
# tiger:zip_right_1
# 15066
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 15001
# name_1
# Sohn Street
# tiger:name_base_1
# Sohn
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15001
# tiger:name_base_1
# State Route 168
# name_1
# Beaver Alley
# name_1
# T758
# tiger:name_base_1
# T758
# tiger:name_base_1
# State Route 989
# name_1
# T316
# tiger:name_base_1
# T316
# tiger:name_base_1
# State Route 989
# tiger:zip_left_1
# 15003
# name_1
# T359
# tiger:name_base_1
# T359
# name_1
# T316
# tiger:name_base_1
# T316
# name_1
# T316
# tiger:name_base_1
# T316
# tiger:name_base_1
# State Route 989
# name_1
# T820
# tiger:name_base_1
# T820
# name_1
# State Route 3030
# name_2
# Pleasant Hills Road
# tiger:name_base_1
# State Route 3030
# tiger:name_base_2
# Pleasant Hills
# tiger:name_type_2
# Rd
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# tiger:zip_left_1
# 15001
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# name_1
# Moore Street
# tiger:name_base_1
# Moore
# tiger:name_type_1
# St
# parking:lane:right
# parallel
# tiger:zip_left_1
# 15005
# tiger:zip_right_1
# 15003
# name_1
# T369
# tiger:name_base_1
# T369
# name_1
# 2nd Street
# tiger:name_base_1
# 2nd
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15074
# tiger:zip_left_1
# 15003
# tiger:zip_left_1
# 15026
# NHS
# yes
# tiger:name_base_1
# State Route 51
# name_1
# T322
# tiger:name_base_1
# T322
# name_1
# T333
# tiger:zip_left_1
# 15009
# name_1
# Locust Street
# tiger:name_base_1
# Locust
# tiger:name_type_1
# St
# tiger:name_base_1
# State Route 288
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:name_base_2
# State Route 168
# tiger:zip_left_1
# 15001
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# NHS
# yes
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# tiger:zip_left_1
# 16141
# tiger:zip_left_1
# 15061
# name_1
# Front Street
# tiger:name_base_1
# Front
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# Burkhardt Avenue
# tiger:name_base_1
# Burkhardt
# tiger:name_type_1
# Ave
# tiger:name_base_1
# United States Highway 30
# tiger:zip_left_1
# 15010
# tiger:zip_right_1
# 15010
# name_1
# T530
# tiger:name_base_1
# T530
# name_1
# T530
# tiger:name_base_1
# T530
# name_1
# Colonial Glenn Estates
# tiger:name_base_1
# Colonial Glenn Estates
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_left_1
# 15005
# tiger:name_base_1
# State Route 288
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# name_1
# Unionville Road
# tiger:name_base_1
# Unionville
# tiger:name_type_1
# Rd
# name_1
# T349
# tiger:name_base_1
# T349
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_left_1
# 15009
# tiger:zip_left_1
# 16115
# tiger:zip_left_1
# 15244
# name_1
# T465
# tiger:name_base_1
# T465
# name_1
# State Route 3030
# tiger:name_base_1
# State Route 3030
# name_1
# State Route 3030
# tiger:name_base_1
# State Route 3030
# tiger:zip_left_1
# 15010
# tiger:zip_right_1
# 15010
# tiger:zip_left_1
# 15009
# tiger:zip_left_2
# 15009
# tiger:zip_right_1
# 15009
# tiger:zip_right_2
# 15009
# tiger:zip_left_1
# 15010
# tiger:name_base_1
# State Route 251
# name_1
# Graham Street
# tiger:name_base_1
# Graham
# tiger:name_type_1
# St
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15074
# tiger:zip_left_1
# 15074
# name_1
# Sr3026
# tiger:name_base_1
# Sr3026
# name_1
# Hetchie Drive
# tiger:name_base_1
# Hetchie
# tiger:name_type_1
# Dr
# name_1
# Glenn
# tiger:name_base_1
# Glenn
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# T 360
# tiger:name_base_1
# T 360
# tiger:name_base_1
# Route 588
# tiger:name_base_2
# State Route 588
# name_1
# Huron Street
# tiger:name_base_1
# Huron
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15077
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:zip_left_1
# 15009
# tiger:zip_left_1
# 15066
# tiger:zip_right_1
# 15066
# name_1
# State Route 3023
# tiger:name_base_1
# State Route 3023
# tiger:name_base_1
# State Route 151
# parking:lane:right
# parallel
# name_1
# Linmar Trail
# tiger:name_base_1
# Linmar
# tiger:name_type_1
# Trl
# tiger:name_base_1
# State Route 4007
# tiger:name_base_1
# State Route 4007
# tiger:zip_left_1
# 15042
# name_1
# Lower Road
# tiger:name_base_1
# Lower
# tiger:name_type_1
# Rd
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# tiger:name_base_2
# State Route 551
# tiger:zip_left_1
# 15009
# tiger:zip_left_2
# 15009
# tiger:zip_left_1
# 16123
# tiger:zip_left_2
# 16123
# tiger:name_base_1
# State Route 18
# tiger:zip_left_1
# 15074
# tiger:zip_right_1
# 15074
# tiger:zip_left_1
# 15010
# name_1
# T359
# name_1
# State Route 3013
# name_1
# State Route 3013
# tiger:name_base_1
# State Route 3013
# name_1
# State Route 3013
# tiger:name_base_1
# State Route 3013
# name_1
# State Route 3013
# tiger:name_base_1
# State Route 3013
# tiger:zip_left_1
# 15001
# parking:lane:both
# parallel
# name_1
# Tevebaugh Hollow Road
# tiger:name_base_1
# Tevebaugh Hollow
# tiger:name_type_1
# Rd
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15081
# tiger:zip_right_1
# 15081
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15074
# tiger:zip_left_1
# 15042
# tiger:zip_right_1
# 15042
# tiger:zip_left_1
# 15010
# name_1
# South R 1022
# tiger:name_base_1
# R 1022
# tiger:name_direction_prefix_1
# S
# tiger:zip_left_1
# 15143
# tiger:zip_left_1
# 15003
# name_1
# T315
# tiger:name_base_1
# T315
# tiger:zip_left_1
# 16157
# name_1
# Hiland Avenue
# tiger:name_base_1
# Hiland
# tiger:name_type_1
# Ave
# tiger:zip_left_1
# 15010
# tiger:name_base_1
# State Route 989
# tiger:zip_left_1
# 16123
# name_1
# State Route 1008
# tiger:name_base_1
# State Route 1008
# tiger:zip_left_1
# 15010
# tiger:zip_left_2
# 15010
# tiger:zip_left_3
# 15010
# name_1
# Township Highway 1038
# tiger:name_base_1
# Township Highway 1038
# tiger:zip_left_1
# 16115
# tiger:zip_left_2
# 16115
# tiger:zip_right_1
# 16115
# tiger:zip_right_2
# 15059
# tiger:zip_left_1
# 15009
# tiger:zip_right_1
# 15009
# name_1
# T450
# tiger:name_base_1
# T450
# tiger:zip_left_1
# 15061
# tiger:zip_right_1
# 15061
# tiger:zip_left_1
# 16123
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_left_1
# 15052
# tiger:zip_right_1
# 15052
# tiger:zip_left_1
# 16117
# tiger:zip_left_2
# 16117
# tiger:zip_right_1
# 16117
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# name_1
# T 488
# tiger:name_base_1
# T 488
# name_1
# T460
# tiger:name_base_1
# T460
# name_1
# Steinbaugh Road
# tiger:name_base_1
# Steinbaugh
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15074
# name_1
# T464
# tiger:name_base_1
# T464
# tiger:zip_left_1
# 15061
# tiger:name_base_1
# State Route 989
# tiger:zip_left_1
# 15074
# tiger:zip_right_1
# 15074
# tiger:name_base_1
# Elmwood
# tiger:name_type_1
# Blvd
# tiger:name_base_1
# Elmwood
# tiger:name_type_1
# Blvd
# tiger:name_base_1
# Elmwood
# tiger:name_type_1
# Blvd
# name_1
# Beech Street
# tiger:name_base_1
# Beech
# tiger:name_type_1
# St
# parking:lane:both
# parallel
# name_1
# T467
# tiger:name_base_1
# T467
# tiger:zip_left_1
# 15043
# tiger:zip_left_2
# 15043
# tiger:zip_left_3
# 15043
# name_1
# T371
# tiger:name_base_1
# T371
# name_1
# T555
# tiger:name_base_1
# T555
# name_1
# T557
# tiger:name_base_1
# T557
# tiger:zip_left_1
# 15061
# tiger:zip_left_2
# 15061
# tiger:zip_right_1
# 15061
# name_1
# T514
# tiger:name_base_1
# T514
# tiger:zip_left_1
# 15001
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15009
# tiger:zip_left_2
# 15009
# tiger:zip_left_3
# 15009
# tiger:zip_left_1
# 15061
# name_1
# T312
# tiger:name_base_1
# T312
# name_1
# Allen Road
# tiger:name_base_1
# Allen
# tiger:name_type_1
# Rd
# name_1
# Cole Street
# tiger:name_base_1
# Cole
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# T370
# tiger:name_base_1
# T370
# name_1
# T370
# tiger:name_base_1
# T370
# name_1
# North Street
# tiger:name_base_1
# North
# tiger:name_type_1
# St
# name_1
# 1st Street
# tiger:name_base_1
# 1st
# tiger:name_type_1
# St
# tiger:zip_left_1
# 16117
# name_1
# Kane Road
# tiger:name_base_1
# Kane
# tiger:name_type_1
# Rd
# parking:lane:both
# parallel
# name_1
# Vance Road
# tiger:name_base_1
# Vance
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15027
# tiger:zip_left_1
# 15003
# parking:lane:both
# parallel
# tiger:zip_left_1
# 16063
# tiger:zip_left_2
# 16063
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# name_1
# T556
# tiger:name_base_1
# T556
# tiger:zip_left_1
# 15027
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# State Route 1009
# tiger:name_base_1
# State Route 1009
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# tiger:zip_left_1
# 15005
# tiger:zip_left_2
# 15005
# name_1
# T300
# tiger:name_base_1
# T300
# name_1
# Township Highway 679
# tiger:name_base_1
# Township Highway 679
# tiger:name_base_1
# State Route 68
# tiger:name_base_1
# State Route 68
# tiger:name_base_2
# Route 68
# tiger:name_base_1
# State Route 68
# tiger:name_base_1
# State Route 68
# tiger:name_base_2
# Route 68
# name_1
# 44th Street
# tiger:name_base_1
# 44th
# tiger:name_type_1
# St
# name_1
# T480
# tiger:name_base_1
# T480
# name_1
# T455
# tiger:name_base_1
# T455
# name_1
# T455
# tiger:name_base_1
# T455
# tiger:zip_left_1
# 15052
# tiger:zip_right_1
# 15003
# tiger:name_base_1
# State Route 168
# tiger:name_base_2
# State Route 551
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# T478
# tiger:name_base_1
# T478
# name_1
# Industry Drive
# tiger:name_base_1
# Industry
# tiger:name_type_1
# Dr
# tiger:zip_left_1
# 16117
# name_1
# Cleveland Street
# tiger:name_base_1
# Cleveland
# tiger:name_type_1
# St
# tiger:zip_left_1
# 15066
# parking:lane:both
# parallel
# name_1
# T312
# tiger:name_base_1
# T312
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15009
# tiger:zip_right_1
# 15009
# name_1
# Jenny Street
# tiger:name_base_1
# Jenny
# tiger:name_type_1
# St
# name_1
# T345
# tiger:name_base_1
# T345
# tiger:name_base_1
# State Route 168
# tiger:zip_left_1
# 15010
# tiger:zip_right_1
# 15010
# tiger:zip_left_1
# 15043
# tiger:zip_left_1
# 15052
# name_1
# Brown Road
# tiger:name_base_1
# Brown
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15066
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# tiger:zip_left_3
# 15001
# tiger:zip_left_4
# 15001
# tiger:zip_right_2
# 15001
# tiger:zip_right_3
# 15001
# tiger:zip_right_4
# 15001
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:name_base_1
# State Route 588
# tiger:zip_left_1
# 15010
# tiger:zip_left_1
# 15066
# tiger:zip_left_2
# 15066
# name_1
# T457
# tiger:name_base_1
# T457
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15061
# tiger:zip_right_2
# 15061
# name_1
# T368
# tiger:name_base_1
# T368
# tiger:zip_left_1
# 15009
# parking:lane:both
# parallel
# name_1
# Cullen Drive
# name_2
# T466
# tiger:name_base_1
# Cullen
# tiger:name_base_2
# T466
# tiger:name_type_1
# Dr
# name_1
# South R 1035
# tiger:name_base_1
# R 1035
# tiger:name_direction_prefix_1
# S
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:zip_left_1
# 16141
# tiger:name_base_1
# State Route 588
# name_1
# T370
# tiger:name_base_1
# T370
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# name_1
# T304
# tiger:name_base_1
# T304
# name_1
# T304
# tiger:name_base_1
# T304
# tiger:zip_left_1
# 15050
# tiger:zip_left_1
# 15001
# tiger:zip_left_1
# 15074
# name_1
# Liberty Road
# parking:lane:both
# parallel
# tiger:zip_left_1
# 15042
# tiger:zip_left_2
# 15042
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# tiger:zip_left_1
# 15009
# tiger:zip_right_1
# 15009
# tiger:name_base_1
# State Route 65
# tiger:zip_left_1
# 15074
# tiger:zip_right_1
# 15074
# destination:ref:to
# US 22
# destination:ref:to
# US 22
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# NHS
# yes
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# tiger:name_base_1
# Beaver Valley
# tiger:name_type_1
# Expy
# tiger:name_base_1
# Beaver Valley
# tiger:name_type_1
# Expy
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# NHS
# yes
# tiger:zip_left_1
# 15061
# tiger:zip_right_1
# 15061
# NHS
# yes
# parking:lane:both
# parallel
# destination:ref:to
# I 376
# NHS
# yes
# turn:lanes:forward
# left|through
# tiger:zip_left_1
# 15061
# tiger:zip_left_2
# 15061
# tiger:name_base_1
# State Route 51
# NHS
# yes
# NHS
# yes
# NHS
# yes
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:zip_left_1
# 15009
# parking:lane:right
# parallel
# destination:ref:to
# PA 68
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# turn:lanes:forward
# left|through;right
# destination:ref:to
# PA 351
# destination:ref:to
# PA 351
# destination:ref:to
# PA 351
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# Orange Beltway
# tiger:name_base_1
# State Route 989
# NHS
# yes
# tiger:name_base_1
# US:PA 51
# NHS
# yes
# tiger:name_base_1
# US:PA 51
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# name_1
# State Route 2006
# tiger:name_base_1
# State Route 2006
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# US:PA 51
# NHS
# yes
# NHS
# yes
# NHS
# yes
# NHS
# yes
# NHS
# yes
# NHS
# yes
# NHS
# yes
# NHS
# yes
# NHS
# yes
# turn:lanes:forward
# through|through;right
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# NHS
# yes
# NHS
# yes
# destination:ref:lanes
# PA 65 North;PA 18 North|PA 68 East;PA 18 South;PA 51 South;PA 65 South
# NHS
# yes
# NHS
# yes
# destination:ref:lanes
# PA 65 North;PA 18 North|PA 68 East;PA 18 South;PA 51 South;PA 65 South
# NHS
# yes
# NHS
# yes
# NHS
# yes
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# destination:ref:to
# PA 68;PA 51 North
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# destination:ref:to
# PA 18 South
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# destination:ref:to
# PA 18 South
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# destination:ref:to
# PA 68;PA 51 North
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# turn:lanes:backward
# through|right
# turn:lanes:forward
# left;through|right
# NHS
# yes
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# destination:ref:lanes
# PA 65 North;PA 18 North|PA 68 East;PA 18 South
# source:ref:penndot
# PennDOT Beaver County Type 10 Map (http://www.dot7.state.pa.us/BPR_pdf_files/Maps/GHS/Roadnames/Beaver_GHSN.PDF)
# tiger:name_base_1
# Route 588
# tiger:name_base_2
# State Route 588
# parking:lane:left
# parallel
# parking:lane:right
# diagonal
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:right
# parallel
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# parking:lane:right
# parallel
# parking:lane:right
# parallel
# parking:lane:both
# parallel
# parking:lane:left
# parallel
# parking:lane:both
# parallel
# tiger:name_base_1
# State Route 351
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# State Route 51
# name_1
# Shousetown Bridge
# tiger:name_base_1
# Shousetown
# tiger:name_type_1
# Brg
# name_1
# Shousetown Bridge
# tiger:name_base_1
# Shousetown
# tiger:name_type_1
# Brg
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:zip_left_1
# 15026
# tiger:zip_right_1
# 15026
# name_1
# State Route 3013
# tiger:name_base_1
# State Route 3013
# name_1
# State Route 3013
# name_1
# T359
# tiger:name_base_1
# T359
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:zip_right_1
# 16141
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# State Route 288
# tiger:name_base_2
# State Route 65
# destination:ref:to:forward
# PA 351
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:zip_right_1
# 16141
# tiger:zip_left_1
# 16141
# tiger:zip_left_2
# 16141
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:name_base_1
# State Route 168
# tiger:name_base_2
# State Route 551
# tiger:name_base_1
# State Route 168
# tiger:name_base_2
# State Route 551
# tiger:name_base_1
# State Route 551
# tiger:name_base_1
# State Route 989
# parking:lane:both
# parallel
# turn:lanes:forward
# left|through;right
# turn:lanes:backward
# left|right
# tiger:name_base_1
# State Route 588
# tiger:name_base_1
# State Route 588
# destination:ref:to
# I 376 East
# tiger:name_base_1
# Moon and Clinton
# tiger:name_type_1
# Rd
# destination:ref:to
# US 30
# destination:ref:to
# US 30
# tiger:zip_left_1
# 15026
# tiger:zip_right_1
# 15026
# tiger:zip_left_1
# 15026
# tiger:zip_right_1
# 15026
# tiger:zip_left_1
# 15001
# tiger:zip_left_1
# 15001
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:zip_right_1
# 16141
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:zip_right_1
# 16141
# destination:ref:lanes
# I 376 Toll West|none
# destination:ref:to:lanes
# none|PA 351
# destination:ref:to
# US 30
# tiger:name_base_1
# State Route 351
# tiger:name_base_1
# State Route 351
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# destination:ref:lanes
# I 76 East|I 76 West
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# turn:lanes:forward
# left|through;right
# NHS
# yes
# tiger:name_base_1
# State Route 51
# parking:lane:right
# parallel
# turn:lanes:backward
# left;through|right
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# State Route 989
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 151
# name_1
# State Route 2006
# tiger:name_base_1
# State Route 2006
# tiger:name_base_1
# State Route 351
# tiger:zip_left_1
# 16141
# tiger:zip_right_1
# 16141
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# State Route 51
# tiger:name_base_1
# US:PA 51
# tiger:name_base_1
# State Route 588
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# FIXME
# What's the street name?
# FIXME
# What's the street name?
# FIXME
# What's the street name?
# FIXME
# What's the street name?
# FIXME
# What's the street name?
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# turn:lanes:forward
# left;through|right
# name_1
# Lower Road
# tiger:name_base_1
# Lower
# tiger:name_type_1
# Rd
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# State Route 288
# tiger:name_base_2
# State Route 65
# name_1
# State Route 1009
# tiger:name_base_1
# State Route 1009
# name_1
# State Route 1005
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# NHS
# yes
# tiger:name_base_1
# State Route 51
# tiger:zip_left_1
# 15010
# tiger:zip_left_2
# 15010
# tiger:zip_left_3
# 15010
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:name_base_1
# United States Highway 30
# tiger:zip_left_1
# 15001
# tiger:zip_right_1
# 15001
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# destination:ref:to
# PA 351
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# State Route 288
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:name_base_1
# Pennsylvania
# tiger:name_type_1
# Tpke
# tiger:zip_left_1
# 15026
# tiger:zip_right_1
# 15026
# destination:ref:lanes
# PA 18 South|PA 551 West
# destination:ref:to:lanes
# none|I 376 Toll
# destination:ref:lanes
# PA 18 South|PA 551 West
# destination:ref:to:lanes
# none|I 376 Toll
# tiger:name_base_1
# State Route 588
# tiger:name_base_1
# State Route 588
# turn:lanes:forward
# through|right
# NHS
# yes
# turn:lanes:forward
# through|through;right
# turn:lanes:backward
# left|through
# turn:lanes:forward
# left
# tiger:name_base_1
# Route 588
# tiger:name_base_2
# State Route 588
# parking:lane:both
# parallel
# destination:ref:lanes:backward
# PA 18 South|PA 551 West
# destination:ref:to:lanes:backward
# none|I 376 Toll
# turn:lanes:backward
# through|right
# parking:lane:right
# parallel
# parking:lane:right
# parallel
# parking:lane:left
# parallel
# parking:lane:right
# diagonal
# parking:lane:right
# parallel
# parking:lane:right
# parallel
# tiger:zip_left_1
# 15026
# tiger:zip_right_1
# 15026
# tiger:zip_left_1
# 15026
# tiger:zip_right_1
# 15026
# FIXME
# What's the street name?
# tiger:name_base_1
# State Route 151
# tiger:name_base_1
# State Route 151
# name_1
# T368
# tiger:name_base_1
# T368
# name_1
# T319
# tiger:name_base_1
# T319
# name_1
# T319
# tiger:name_base_1
# T319
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# name_1
# State Route 3022
# tiger:name_base_1
# State Route 3022
# turn:lanes:forward
# left|through;right
# FIXME
# verify
# turn:lanes:backward
# left|right
# tiger:zip_left_1
# 15001
# tiger:zip_left_2
# 15001
# tiger:zip_left_3
# 15001
# tiger:zip_left_4
# 15001
# tiger:zip_right_2
# 15001
# tiger:zip_right_3
# 15001
# tiger:zip_right_4
# 15001
# plant:output:electricity
# 1890 MW
# destination:ref:to
# I 376 West
# mtb:scale:uphill
# 5
# turn:lanes:backward
# left|through
# turn:lanes:forward
# none
# turn:lanes:backward
# left|through;right
# turn:lanes:forward
# none
# destination:ref:to
# PA 51 North
# destination:ref:to
# PA 65 South;PA 51 South
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# turn:lanes:backward
# none|none
# turn:lanes:forward
# left|none|none
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# turn:lanes:backward
# left|through|through;right
# turn:lanes:forward
# none|none
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# turn:lanes:backward
# none|none
# turn:lanes:forward
# left|none|none
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# turn:lanes:backward
# none|none
# turn:lanes:forward
# left|through|through;right
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# ...
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:right
# parallel
# turn:lanes:backward
# left;through|right
# parking:lane:both
# parallel
# parking:lane:left
# parallel
# turn:lanes:forward
# left;through|right
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# turn:lanes:forward
# left|through|through
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# destination:ref:lanes:forward
# PA 551 West|PA 18 North
# destination:ref:to:lanes:forward
# I 376 Toll|none
# parking:lane:left
# parallel
# turn:lanes:forward
# left|through
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:right
# parallel
# turn:lanes:backward
# through|right
# parking:lane:left
# parallel
# turn:lanes:forward
# left|right
# parking:lane:left
# parallel
# turn:lanes:forward
# left|through
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:right
# parallel
# turn:lanes:backward
# left|through;right
# parking:lane:left
# parallel
# turn:lanes:forward
# left|through;right
# turn:lanes:forward
# left|through;right
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:left
# parallel
# parking:lane:right
# parallel
# turn:lanes:backward
# left|through
# turn:lanes:backward
# left|through
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# turn:lanes:backward
# left|through;right
# turn:lanes:backward
# left;through|right
# destination:ref:lanes
# ||I 76 Toll;PATP
# destination:ref:lanes
# ||I 76 Toll;PATP
# name_1
# Beaver Alley
# name_1
# Beaver Alley
# name_1
# Beaver Alley
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# NHS
# yes
# NHS
# yes
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# building:levels:underground
# 1
# building:levels:underground
# 1
# tiger:name_base_1
# State Route 51
# name_1
# Clinton Flaugherty Road
# tiger:name_base_1
# Clinton Flaugherty
# tiger:name_type_1
# Rd
# name_1
# Clinton Flaugherty Road
# tiger:name_base_1
# Clinton Flaugherty
# tiger:name_type_1
# Rd
# tiger:zip_left_1
# 15010
# tiger:zip_left_2
# 15010
# tiger:zip_left_3
# 15010
# tiger:name_base_1
# State Route 68
# tiger:name_base_2
# Route 68
# tiger:name_base_1
# State Route 68
# tiger:name_base_2
# Route 68
# sport_1
# hockey
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 51
# NHS
# yes
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# turn:lanes:backward
# none|none
# turn:lanes:forward
# left|through|through;right
# tiger:name_base_1
# State Route 65
# NHS
# yes
# tiger:name_base_1
# State Route 68
# NHS
# yes
# tiger:name_base_1
# State Route 68
# tiger:zip_left_1
# 15074
# tiger:zip_right_1
# 15074
# tiger:zip_left_1
# 15074
# tiger:zip_right_1
# 15074
# tiger:zip_left_1
# 15074
# destination:ref:to
# PA 351
# destination:ref:backward
# I 376;I 76;PATP
# destination:ref:to:forward
# PA 351
# destination:ref:to
# I 76;PATP
# generator:output:electricity
# 15.3 kW
# tiger:zip_left_1
# 15003
# parking:lane:left
# parallel
# parking:lane:right
# diagonal
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:left
# parallel
# parking:lane:right
# diagonal
# parking:lane:both
# parallel
# parking:lane:left
# parallel
# parking:lane:right
# diagonal
# parking:lane:both
# parallel
# parking:lane:both
# parallel
# parking:lane:left
# parallel
# parking:lane:right
# diagonal
# NHS
# yes
# NHS
# yes
# tiger:name_base_1
# State Route 65
# NHS
# yes
# tiger:name_base_1
# State Route 65
# NHS
# yes
# tiger:name_base_1
# State Route 68
# parking:lane:both
# parallel
# FIXME
# What's the street name?
# name_1
# River Street
# tiger:name_base_1
# River
# tiger:name_type_1
# St
# name_1
# River Street
# tiger:name_base_1
# River
# tiger:name_type_1
# St
# NHS
# yes
# tiger:name_base_1
# State Route 51
# generator:output:electricity
# yes
# tiger:zip_left_1
# 16136
# tiger:zip_right_1
# 16136
# tiger:zip_left_1
# 16136
# tiger:zip_right_1
# 16136
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# Moon and Clinton
# tiger:name_type_1
# Rd
# turn:lanes:both_ways
# left
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 65
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# tiger:name_base_2
# State Route 551
# name_1
# Township Highway 679
# tiger:name_base_1
# Township Highway 679
# tiger:name_base_1
# State Route 168
# tiger:name_base_1
# State Route 168
# tiger:name_base_2
# State Route 551
# name_1
# I-341
# name_2
# Rambo Road
# tiger:name_base_1
# I-341
# tiger:name_base_2
# Rambo
# tiger:name_type_2
# Rd
# plant:output:electricity
# 2741 MW
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# South Heights
# tiger:NAMELSAD
# South Heights borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 72216
# tiger:PLACENS
# 01214891
# tiger:PLCIDFP
# 4272216
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 25
# tiger:MTFCC
# G4110
# tiger:NAME
# Aliquippa
# tiger:NAMELSAD
# Aliquippa city
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 00820
# tiger:PLACENS
# 01214861
# tiger:PLCIDFP
# 4200820
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Ambridge
# tiger:NAMELSAD
# Ambridge borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 02288
# tiger:PLACENS
# 01214862
# tiger:PLCIDFP
# 4202288
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Baden
# tiger:NAMELSAD
# Baden borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 03736
# tiger:PLACENS
# 01214863
# tiger:PLCIDFP
# 4203736
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Beaver
# tiger:NAMELSAD
# Beaver borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 04688
# tiger:PLACENS
# 01214864
# tiger:PLCIDFP
# 4204688
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Eastvale
# tiger:NAMELSAD
# Eastvale borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 21968
# tiger:PLACENS
# 01214870
# tiger:PLCIDFP
# 4221968
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Patterson Heights
# tiger:NAMELSAD
# Patterson Heights borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 58384
# tiger:PLACENS
# 01214888
# tiger:PLCIDFP
# 4258384
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 25
# tiger:MTFCC
# G4110
# tiger:NAME
# Beaver Falls
# tiger:NAMELSAD
# Beaver Falls city
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 04792
# tiger:PLACENS
# 01214865
# tiger:PLCIDFP
# 4204792
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# West Mayfield
# tiger:NAMELSAD
# West Mayfield borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 83472
# tiger:PLACENS
# 01214893
# tiger:PLCIDFP
# 4283472
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Koppel
# tiger:NAMELSAD
# Koppel borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 40400
# tiger:PLACENS
# 01214882
# tiger:PLCIDFP
# 4240400
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Bridgewater
# tiger:NAMELSAD
# Bridgewater borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 08632
# tiger:PLACENS
# 01214866
# tiger:PLCIDFP
# 4208632
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Conway
# tiger:NAMELSAD
# Conway borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 15872
# tiger:PLACENS
# 01214867
# tiger:PLCIDFP
# 4215872
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Rochester
# tiger:NAMELSAD
# Rochester borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 65392
# tiger:PLACENS
# 02086684
# tiger:PLCIDFP
# 4265392
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Freedom
# tiger:NAMELSAD
# Freedom borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 27712
# tiger:PLACENS
# 01214875
# tiger:PLCIDFP
# 4227712
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Monaca
# tiger:NAMELSAD
# Monaca borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 50320
# tiger:PLACENS
# 01214884
# tiger:PLCIDFP
# 4250320
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# East Rochester
# tiger:NAMELSAD
# East Rochester borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 21752
# tiger:PLACENS
# 01214869
# tiger:PLCIDFP
# 4221752
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Economy
# tiger:NAMELSAD
# Economy borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 22264
# tiger:PLACENS
# 01214871
# tiger:PLCIDFP
# 4222264
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# U2
# tiger:CPI
# N
# tiger:FUNCSTAT
# S
# tiger:LSAD
# 57
# tiger:MTFCC
# G4210
# tiger:NAME
# Patterson Township
# tiger:NAMELSAD
# Patterson Township CDP
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 58416
# tiger:PLACENS
# 02389647
# tiger:PLCIDFP
# 4258416
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Fallston
# tiger:NAMELSAD
# Fallston borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 25152
# tiger:PLACENS
# 01214873
# tiger:PLCIDFP
# 4225152
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# New Brighton
# tiger:NAMELSAD
# New Brighton borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 53288
# tiger:PLACENS
# 01214885
# tiger:PLCIDFP
# 4253288
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Georgetown
# tiger:NAMELSAD
# Georgetown borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 28824
# tiger:PLACENS
# 01214876
# tiger:PLCIDFP
# 4228824
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Glasgow
# tiger:NAMELSAD
# Glasgow borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 29392
# tiger:PLACENS
# 01214877
# tiger:PLCIDFP
# 4229392
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Shippingport
# tiger:NAMELSAD
# Shippingport borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 70376
# tiger:PLACENS
# 01214890
# tiger:PLCIDFP
# 4270376
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Industry
# tiger:NAMELSAD
# Industry borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 36944
# tiger:PLACENS
# 01214881
# tiger:PLCIDFP
# 4236944
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Ohioville
# tiger:NAMELSAD
# Ohioville borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 56432
# tiger:PLACENS
# 01214887
# tiger:PLCIDFP
# 4256432
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Midland
# tiger:NAMELSAD
# Midland borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 49184
# tiger:PLACENS
# 01214883
# tiger:PLCIDFP
# 4249184
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Bell Acres
# tiger:NAMELSAD
# Bell Acres borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 05216
# tiger:PLACENS
# 01214766
# tiger:PLCIDFP
# 4205216
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Coraopolis
# tiger:NAMELSAD
# Coraopolis borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 16144
# tiger:PLACENS
# 01214784
# tiger:PLCIDFP
# 4216144
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Edgeworth
# tiger:NAMELSAD
# Edgeworth borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 22576
# tiger:PLACENS
# 01214792
# tiger:PLCIDFP
# 4222576
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Leetsdale
# tiger:NAMELSAD
# Leetsdale borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 42392
# tiger:PLACENS
# 01214804
# tiger:PLCIDFP
# 4242392
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Osborne
# tiger:NAMELSAD
# Osborne borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 57200
# tiger:PLACENS
# 01214815
# tiger:PLCIDFP
# 4257200
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Sewickley Heights
# tiger:NAMELSAD
# Sewickley Heights borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 69400
# tiger:PLACENS
# 01214824
# tiger:PLCIDFP
# 4269400
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Big Beaver
# tiger:NAMELSAD
# Big Beaver borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 06240
# tiger:PLACENS
# 01217435
# tiger:PLCIDFP
# 4206240
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Darlington
# tiger:NAMELSAD
# Darlington borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 18192
# tiger:PLACENS
# 01214868
# tiger:PLCIDFP
# 4218192
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Frankfort Springs
# tiger:NAMELSAD
# Frankfort Springs borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 27312
# tiger:PLACENS
# 01214874
# tiger:PLCIDFP
# 4227312
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Homewood
# tiger:NAMELSAD
# Homewood borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 35488
# tiger:PLACENS
# 01214879
# tiger:PLCIDFP
# 4235488
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# Hookstown
# tiger:NAMELSAD
# Hookstown borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 35576
# tiger:PLACENS
# 01214880
# tiger:PLCIDFP
# 4235576
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# C5
# tiger:CPI
# N
# tiger:FUNCSTAT
# A
# tiger:LSAD
# 21
# tiger:MTFCC
# G4110
# tiger:NAME
# New Galilee
# tiger:NAMELSAD
# New Galilee borough
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 53592
# tiger:PLACENS
# 01214886
# tiger:PLCIDFP
# 4253592
# tiger:STATEFP
# 42
# is_in:iso_3166_2
# US:PA
# tiger:CLASSFP
# U2
# tiger:CPI
# N
# tiger:FUNCSTAT
# S
# tiger:LSAD
# 57
# tiger:MTFCC
# G4210
# tiger:NAME
# Carnot-Moon
# tiger:NAMELSAD
# Carnot-Moon CDP
# tiger:PCICBSA
# N
# tiger:PCINECTA
# N
# tiger:PLACEFP
# 11348
# tiger:PLACENS
# 02389282
# tiger:PLCIDFP
# 4211348
# tiger:STATEFP
# 42
# destination:ref:to
# I 376
# destination:ref:to
# I 376
# destination:ref:to
# I 376
# is_in:iso_3166_2
# US:PA
# destination:ref:to
# I 376 Toll;PA 51
# destination:ref:to
# I 376 Toll;PA 51
# destination:ref:to
# PA 51;I 376 Toll
# destination:ref:to
# PATP
# destination:ref:to
# I 376
# destination:ref:to
# PATP
# destination:ref:to
# I 376 Toll
# destination:ref:to
# I 376 Toll
# {'lower': 116841, 'lower_colon': 61630, 'other': 3080, 'problemchars': 0}

# %%
# Finding unique k (tag attrib['k']) and count

def unique_keys(filename):
    distinct_keys=[]
    count=1
    #loop and count unique elements
    EL=get_element(filename, tags=('node', 'way', 'relation'))
    for element in EL:
        if element.tag=='node' or element.tag=='way':
            for tag in element.iter('tag'):
                if tag.attrib['k'] not in distinct_keys:
                    distinct_keys.append(tag.attrib['k'])
                    count+=1
    distinct_keys.sort()
    print("Total of unique keys is {}".format(count))
    
    return distinct_keys
      
    pprint.pprint(distinct_keys)
    
                
unique_keys(OSM_FILE)  # Using real file as input to audit the addr:street key
# Out:
# Total of unique keys is 430
# ['FIXME',
#  'NHS',
#  'abandoned:amenity',
#  'abandoned:railway',
#  'access',
#  'addr:city',
#  'addr:country',
#  'addr:housename',
#  'addr:housenumber',
#  'addr:postcode',
#  'addr:state',
#  'addr:street',
#  'addr:unit',
#  'admin_level',
#  'aerodrome:type',
#  'aeroway',
#  'air_conditioning',
#  'airmark',
#  'alt_name',
#  'amenity',
#  'amenity_1',
#  'area',
#  'atm',
#  'backrest',
#  'bar',
#  'barrier',
#  'basin',
#  'beacon:code',
#  'beacon:frequency',
#  'beacon:type',
#  'bicycle',
#  'bicycle_parking',
#  'board_type',
#  'boat',
#  'boundary',
#  'brand',
#  'brand:wikidata',
#  'brand:wikipedia',
#  'brewery',
#  'bridge',
#  'bridge:name',
#  'building',
#  'building:levels',
#  'building:levels:underground',
#  'building:material',
#  'building:part',
#  'building_1',
#  'bus',
#  'cables',
#  'capacity',
#  'capacity:disabled',
#  'capacity:parent',
#  'capacity:women',
#  'category',
#  'census:population',
#  'centre_turn_lane',
#  'communication:mobile_phone',
#  'construction',
#  'contact:phone',
#  'contact:website',
#  'content',
#  'covered',
#  'craft',
#  'created_by',
#  'crossing',
#  'crossing:barrier',
#  'crossing:bell',
#  'crossing:island',
#  'crossing:light',
#  'crossing_ref',
#  'cuisine',
#  'cycleway',
#  'cycleway:left',
#  'deep_draft',
#  'delivery',
#  'denomination',
#  'departures_board',
#  'description',
#  'designation',
#  'destination',
#  'destination:lanes',
#  'destination:ref',
#  'destination:ref:backward',
#  'destination:ref:lanes',
#  'destination:ref:lanes:backward',
#  'destination:ref:lanes:forward',
#  'destination:ref:to',
#  'destination:ref:to:forward',
#  'destination:ref:to:lanes',
#  'destination:ref:to:lanes:backward',
#  'destination:ref:to:lanes:forward',
#  'destination:street:lanes',
#  'destination:symbol',
#  'direction',
#  'dispensing',
#  'disused:leisure',
#  'disused:name',
#  'drive_in',
#  'drive_through',
#  'ele',
#  'electrified',
#  'email',
#  'emergency',
#  'end_date',
#  'entrance',
#  'expressway',
#  'faa',
#  'fax',
#  'fee',
#  'fence_type',
#  'fireplace',
#  'fixme',
#  'flashing_lights',
#  'floating',
#  'foot',
#  'footway',
#  'ford',
#  'frequency',
#  'fuel',
#  'fuel:biodiesel',
#  'fuel:biogas',
#  'fuel:cng',
#  'fuel:diesel',
#  'fuel:e10',
#  'fuel:e85',
#  'fuel:octane_95',
#  'fuel:octane_98',
#  'gauge',
#  'generator:method',
#  'generator:output:electricity',
#  'generator:source',
#  'generator:type',
#  'gnis:Class',
#  'gnis:County',
#  'gnis:County_num',
#  'gnis:ST_alpha',
#  'gnis:ST_num',
#  'gnis:county_id',
#  'gnis:county_name',
#  'gnis:created',
#  'gnis:feature_id',
#  'gnis:feature_type',
#  'gnis:id',
#  'gnis:import_uuid',
#  'gnis:reviewed',
#  'gnis:state_id',
#  'golf',
#  'golf_cart',
#  'guide_type',
#  'healthcare',
#  'healthcare:speciality',
#  'height',
#  'heritage',
#  'heritage:operator',
#  'hgv',
#  'hgv:lanes',
#  'highway',
#  'historic',
#  'hoops',
#  'horse',
#  'iata',
#  'icao',
#  'import_uuid',
#  'incline',
#  'indoor',
#  'industrial',
#  'information',
#  'inscription',
#  'intermittent',
#  'internet_access',
#  'is_in',
#  'junction',
#  'junction:ref',
#  'landuse',
#  'lanes',
#  'lanes:backward',
#  'lanes:both_ways',
#  'lanes:forward',
#  'layer',
#  'lcn',
#  'leaf_cycle',
#  'leisure',
#  'length',
#  'level',
#  'lit',
#  'loc_name',
#  'local_ref',
#  'location',
#  'lock',
#  'lock_name',
#  'man_made',
#  'manhole',
#  'material',
#  'maxheight',
#  'maxspeed',
#  'maxspeed:advisory',
#  'maxspeed:advisory:backward',
#  'maxspeed:advisory:forward',
#  'maxspeed:backward',
#  'maxspeed:forward',
#  'maxspeed:hgv',
#  'maxspeed:hgv:forward',
#  'maxspeed:source',
#  'maxstay',
#  'memorial',
#  'memorial:type',
#  'military',
#  'monitoring_station',
#  'mooring',
#  'motor_vehicle',
#  'mtb:scale',
#  'mtb:scale:uphill',
#  'name',
#  'name:backward',
#  'name:en',
#  'name:forward',
#  'name:ru',
#  'name_1',
#  'name_2',
#  'natural',
#  'navigationaid',
#  'network',
#  'network:wikidata',
#  'noexit',
#  'noname',
#  'noref',
#  'note',
#  'note:lanes',
#  'note:old_railway_operator',
#  'nudism',
#  'odbl',
#  'odbl:note',
#  'office',
#  'official_name',
#  'old_name',
#  'old_railway_operator',
#  'old_ref',
#  'old_ref:legislative',
#  'old_ref_legislative',
#  'oneway',
#  'oneway:bicycle',
#  'oneway:foot',
#  'open_air',
#  'opened',
#  'opening_hours',
#  'opening_hours:emergency',
#  'opening_hours:rubbish',
#  'operator',
#  'operator:type',
#  'operator:wikidata',
#  'operator:wikipedia',
#  'outdoor_seating',
#  'ownership',
#  'par',
#  'park_ride',
#  'parking',
#  'parking:lane:both',
#  'parking:lane:left',
#  'parking:lane:right',
#  'passenger_lines',
#  'payment:cash',
#  'payment:credit_cards',
#  'payment:debit_cards',
#  'payment:e_zpass',
#  'payment:license_plate',
#  'payment:mastercard',
#  'payment:visa',
#  'phone',
#  'phone_1',
#  'pipeline',
#  'place',
#  'plant:output:electricity',
#  'plant:source',
#  'playground',
#  'population',
#  'power',
#  'protect_class',
#  'protection_title',
#  'psv',
#  'public_transport',
#  'radar',
#  'railway',
#  'railway:position',
#  'railway:signal:direction',
#  'railway:signal:position',
#  'railway:switch',
#  'railway:track_ref',
#  'railway:turnout_side',
#  'ramp',
#  'razed:building',
#  'rcn_ref',
#  'recycling:cans',
#  'recycling:glass',
#  'recycling:plastic_bottles',
#  'recycling_type',
#  'ref',
#  'ref:isil',
#  'ref:left',
#  'ref:nrhp',
#  'ref:penndot',
#  'ref:right',
#  'ref:walmart',
#  'religion',
#  'removed:bridge',
#  'removed:highway',
#  'reservation',
#  'residential',
#  'roof',
#  'roof:levels',
#  'route',
#  'screen',
#  'second_hand',
#  'self_service',
#  'service',
#  'shelter',
#  'shelter_type',
#  'ship',
#  'shop',
#  'short_name',
#  'sidewalk',
#  'smoking',
#  'social_facility',
#  'social_facility:for',
#  'socket:chademo',
#  'socket:type1',
#  'source',
#  'source:access',
#  'source:addr',
#  'source:bicycle',
#  'source:bridge',
#  'source:building',
#  'source:construction',
#  'source:deep_draft',
#  'source:description',
#  'source:geometry',
#  'source:height',
#  'source:hgv',
#  'source:maxheight',
#  'source:maxspeed',
#  'source:motor_vehicle',
#  'source:name',
#  'source:oneway',
#  'source:pkey',
#  'source:ref',
#  'source:ref:penndot',
#  'source:shop',
#  'source:start_date',
#  'source:tunnel',
#  'source_opened',
#  'source_ref',
#  'sport',
#  'sport_1',
#  'start_date',
#  'stop',
#  'studio',
#  'substance',
#  'supervised',
#  'surface',
#  'surveillance:type',
#  'tactile_paving',
#  'takeaway',
#  'tidal',
#  'tiger:cfcc',
#  'tiger:county',
#  'tiger:name_base',
#  'tiger:name_base_1',
#  'tiger:name_base_2',
#  'tiger:name_direction_prefix',
#  'tiger:name_direction_prefix_1',
#  'tiger:name_direction_suffix',
#  'tiger:name_type',
#  'tiger:name_type_1',
#  'tiger:name_type_2',
#  'tiger:reviewed',
#  'tiger:separated',
#  'tiger:source',
#  'tiger:tlid',
#  'tiger:upload_uuid',
#  'tiger:zip',
#  'tiger:zip_left',
#  'tiger:zip_left_1',
#  'tiger:zip_left_2',
#  'tiger:zip_left_3',
#  'tiger:zip_left_4',
#  'tiger:zip_right',
#  'tiger:zip_right_1',
#  'tiger:zip_right_2',
#  'tiger:zip_right_3',
#  'tiger:zip_right_4',
#  'tiger:zip_right_6',
#  'toilets:wheelchair',
#  'toll',
#  'tourism',
#  'tower:construction',
#  'tower:type',
#  'tracktype',
#  'traffic_signals',
#  'traffic_signals:direction',
#  'trail_visibility',
#  'tram',
#  'tunnel',
#  'turn',
#  'turn:backward',
#  'turn:forward',
#  'turn:lanes',
#  'turn:lanes:backward',
#  'turn:lanes:both_ways',
#  'turn:lanes:forward',
#  'type',
#  'unsigned',
#  'unsigned_ref',
#  'url',
#  'usage',
#  'vehicle',
#  'vending',
#  'voltage',
#  'voltage-high',
#  'wall',
#  'water',
#  'water_source',
#  'waterway',
#  'website',
#  'wetland',
#  'wheelchair',
#  'width',
#  'wifi',
#  'wikidata',
#  'wikipedia',
#  'wires']

# %%
# Auditing Street Names
street_type_re = re.compile(r'\b\S+\.?$', re.IGNORECASE)

expected = ["Street", "Avenue", "Boulevard", "Drive", "Court", "Place", "Square", "Lane", "Road", 
            "Trail", "Parkway", "Commons","Freeway","Circle","Strand","Sterling","Way","Highway",
            "Terrace","South","East","West","North"]

# Here are the corrections for different road/street types, Referenced from Udacity Course & GitHub; 
# I also added a few I noticed in my listings.
mapping = {
            " St ": " Street ",
            " St.": " Street ",
            " Rd.": " Road ",
            " Rd ": " Road ",
            " Rd": " Road ",
            " Ave ": " Avenue ", 
            " Ave.": " Avenue ",
            " Av ": " Avenue ", 
            " Dr ": " Drive ",
            " Dr.": " Drive",
            " Blvd ": " Boulevard ",
            " Blvd": " Boulevard",
            " Blvd.": " Boulevard",
            " Ct ": " Centre ",
            " Ctr": " Centre",
            " Pl ": " Place ",
            " Ln ": " Lane ",
            " Cir ": " Circle ",
            " Wy": " Way ",
            " Tpke ": " Turnpike ",
            " S ": " South ",
            " E ": " East ",
            " W ": " West ",
            " N ": "North"
}


def audit_street_type(street_types, street_name):
    m = street_type_re.search(street_name)
    if m:
        street_type = m.group()
        if street_type not in expected:
            street_types[street_type].add(street_name)


def is_street_name(elem):
    return (elem.attrib['k'] == "addr:street")


def audit(filename):
    f = open(filename, "r")
    street_types = defaultdict(set)
    for event, elem in ET.iterparse(filename, events=("start",)):
        if elem.tag == "node" or elem.tag == "way":
            for tag in elem.iter("tag"):
                if is_street_name(tag):
                    audit_street_type(street_types, tag.attrib['v'])
            elem.clear()        
    f.close()
    return street_types

def update_name(name, mapping):
    for key,value in mapping.items():
        if key in name:
            return name.replace(key,value)
    return name        

st_types = audit(OSM_FILE)

pprint.pprint(dict(st_types))
for st_type, ways in st_types.items():
    for name in ways:
        better_name = update_name(name, mapping)
        print (name, "=>", better_name)
# Out:
# {'151': {'State Route 151'},
#  '18': {'PA 18', 'State Route 18'},
#  '30': {'State Route 30'},
#  'Blvd': {'Elmwood Blvd'},
#  'Center': {'Quaker Village Shopping Center'},
#  'Centre': {'Chippewa Towne Centre', 'Chippewa Town Centre'},
#  'Extended': {'Crescent Boulevard Extended',
#               'Maple Street Extended',
#               'West End Avenue Extended'},
#  'Extension': {'Hookstown Road Extension'},
#  'Oaks': {'Colonial Oaks'},
#  'Rd': {'Kane Rd'},
#  'Rossway': {'Rossway'},
#  'rd': {'Broadhead rd'}}
# Quaker Village Shopping Center => Quaker Village Shopping Center
# State Route 30 => State Route 30
# Colonial Oaks => Colonial Oaks
# PA 18 => PA 18
# State Route 18 => State Route 18
# Chippewa Towne Centre => Chippewa Towne Centre
# Chippewa Town Centre => Chippewa Town Centre
# Kane Rd => Kane Road
# Rossway => Rossway
# Maple Street Extended => Maple Street Extended
# Crescent Boulevard Extended => Crescent Boulevard Extended
# West End Avenue Extended => West End Avenue Extended
# Broadhead rd => Broadhead rd
# Hookstown Road Extension => Hookstown Road Extension
# State Route 151 => State Route 151
# Elmwood Blvd => Elmwood Boulevard

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0bd7cc164ae0> in <module>
#      39
#      40 if __name__ == '__main__':
# ---> 41     process_map(OSM_PATH, validate=True)
#
# <ipython-input-25-0bd7cc164ae0> in process_map(file_in, validate)
#      23
#      24         for element in get_element(file_in, tags=('node', 'way')):
# ---> 25             el = shape_element(element)
#      26             if el:
#      27                 if validate is True:
#
# <ipython-input-23-a489d7b62286> in shape_element(element, node_attr_fields, way_attr_fields, problem_chars, default_tag_type)
#     209                     continue
#     210
# --> 211                 elif match_two_colons:
#     212                     tag ['id'] = element.attrib['id']
#     213                     tag ['type'] = child.attrib['k'].split(':')[0]
#
# NameError: name 'match_two_colons' is not defined

# %% [markdown]
# ## References
# 1. Github
# 2. stackoverflow
# 3. Udacity course materials
